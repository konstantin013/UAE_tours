# %%
import numpy as np
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
import plotly.offline as ply
import plotly.graph_objs as go

ply.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import statsmodels.api as sm

# %% [markdown]
# # Считывание данных

# %% [markdown]
# Считываем данные, даты, преобразуем в даты, числа в числа

# %%
df = pd.read_csv('data.csv', decimal=',')
df['d1'] = pd.to_datetime(df['date_range'].map(lambda s: s.split()[0]), dayfirst=True)
df['d2'] = pd.to_datetime(df['date_range'].map(lambda s: s.split()[2]), dayfirst=True)
df = df[['date_range', 'd1', 'd2', 'avg_price', 'avg_price_conc', 'volume']]
df['volume'] = df['volume'].replace('\xa0', np.NaN).astype('float')

# %%
df.head()
# Out:
#                 date_range         d1         d2  avg_price  avg_price_conc  \
# 0  12.03.2018 - 18.03.2018 2018-03-12 2018-03-18  103197.80       125185.20
# 1  19.03.2018 - 25.03.2018 2018-03-19 2018-03-25  107808.30       111489.70
# 2  26.03.2018 - 01.04.2018 2018-03-26 2018-04-01   92518.58        98027.54
# 3  02.04.2018 - 08.04.2018 2018-04-02 2018-04-08   80068.75        98274.79
# 4  09.04.2018 - 15.04.2018 2018-04-09 2018-04-15   97560.45       128452.00
#
#    volume
# 0   197.0
# 1   155.0
# 2   124.0
# 3   131.0
# 4   109.0

# %% [markdown]
# * date_range - указанный период
# * avg_price - Средняя цена «ОАЭ ТУР», руб./заказ
# * avg_price_conc - Средняя цена конкурента, руб./заказ
# * volume - Факт продаж, заказов

# %% [markdown]
# Воспользуемся сервисом yandex wordstat https://wordstat.yandex.ru/ В качестве запроса введём "туры в оаэ". Также можно выбрать варианты группировки по месяцам или по неделям. Хотелось бы выбрать группировку по неделям, но, к сожалению, если так сделать, то он выдает данные только начиная с 09.07.2018 (т.е. примерно за последний год), а если по месяцам, то начиная с 01.07.2017 (т.е. примерно за последние 2 года). Поэтому пришлось группировать данные по месяцам. Весь запрос доступен по ссылке: https://wordstat.yandex.ru/#!/history?regions=213&words=%D1%82%D1%83%D1%80%D1%8B%20%D0%B2%20%D0%BE%D0%B0%D1%8D
# Данные были скопированы в файл yandex_data_monthly.csv

# %% [markdown]
# #### Считываем данные из yandex wordstat

# %%
yandex_df_monthly = pd.read_csv('yandex_data_monthly.csv', decimal=',')

yandex_df_monthly['d'] = \
pd.to_datetime(yandex_df_monthly['period'].map(lambda s: s.split()[0]), dayfirst=True)

yandex_df_monthly['d2'] = \
pd.to_datetime(yandex_df_monthly['period'].map(lambda s: s.split()[2]), dayfirst=True)

yandex_df_monthly = yandex_df_monthly[['period', 'd', 'd2', 'absolute', 'relative']]

# %%
yandex_df_monthly.head()
# Out:
#                     period          d         d2  absolute  relative
# 0  01.07.2017 - 31.07.2017 2017-07-01 2017-07-31     23181  0.000004
# 1  01.08.2017 - 31.08.2017 2017-08-01 2017-08-31     28301  0.000004
# 2  01.09.2017 - 30.09.2017 2017-09-01 2017-09-30     36927  0.000005
# 3  01.10.2017 - 31.10.2017 2017-10-01 2017-10-31     49118  0.000006
# 4  01.11.2017 - 30.11.2017 2017-11-01 2017-11-30     45689  0.000006

# %% [markdown]
# * period - промежуток дат
# * absolute - абсолютное число запросов
# * relative - относительное число запросов

# %% [markdown]
# #### Добавляем данные из yandex wordstat

# %%
df = df\
.assign(d = lambda df: df['d1'].values.astype('datetime64[M]').astype('datetime64[ns]'))\
.merge(yandex_df_monthly[['d', 'absolute']], how='left', on='d')\
.rename(mapper={'absolute': 'yandex_query'}, axis=1)\
.drop('d', axis=1)

# %% [markdown]
# Разумно предположить, что спрос зависит от разности цен. Построим два поля: абсолютная и относительная разницы цен

# %%
df['price_dif'] = df['avg_price'] - df['avg_price_conc']
df['price_dif_prc'] = df['price_dif'] / df['avg_price']

# %% [markdown]
# Отделяем неразмеченную выборку, продажи преобразуем к int

# %%
df_full = df.copy()
df = df[df['volume'].notna()]
df['volume'] = df['volume'].astype('int')

# %% [markdown]
# # Первичный анализ

# %% [markdown]
# Построим график по изначальным данным: цены "ОАЭ Тур" и конуерентов и объёмы продаж "ОАЭ Тур"

# %%
data_plot = [    
    
    go.Scatter(
        x=df_full['d1'],
        y=df_full['avg_price'],
        name='avg_price'
    ),
    
    go.Scatter(
        x=df_full['d1'],
        y=df_full['avg_price_conc'],
        name='avg_price_concurrent'
    ), 
    
    go.Bar(
        x=df_full['d1'],
        y=df_full['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y2',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="c57369f2-233a-4170-a578-1b0c76c56f38" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'c57369f2-233a-4170-a578-1b0c76c56f38',
#             [{"name": "avg_price", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [103197.8, 107808.3, 92518.58, 80068.75, 97560.45, 93533.1, 105465.4, 103581.3, 82913.93, 114749.3, 69152.92, 76651.25, 85033.17, 99000.1, 107350.8, 95263.96, 110204.3, 110548.9, 116078.3, 128062.3, 130148.6, 96543.92, 87305.38, 99806.33, 116965.9, 78996.63, 87086.05, 113281.9, 103519.1, 135438.3, 106349.8, 110644.8, 94664.13, 90980.85, 102545.0, 121821.6, 145647.3, 143754.8, 168935.1, 125785.3, 103407.4, 99600.5, 106651.7, 101673.5, 123099.7, 119102.7, 101896.1, 124413.5, 125538.7, 111693.3, 112086.9, 85283.17], "type": "scatter", "uid": "c3472dbe-a6cc-11e9-8637-0008caf36d06"}, {"name": "avg_price_concurrent", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [125185.2, 111489.7, 98027.54, 98274.79, 128452.0, 97903.89, 111031.7, 109069.9, 106719.1, 93182.47, 89318.94, 101019.4, 89029.84, 95122.07, 105820.8, 98585.11, 100714.9, 104181.4, 89461.0, 104517.7, 102972.8, 101899.9, 90809.69, 104769.0, 101440.8, 87243.0, 95416.29, 104672.6, 102271.3, 103567.9, 111031.3, 102882.1, 121788.3, 105228.1, 114407.0, 129676.5, 115160.8, 108358.1, 135743.5, 121518.2, 95927.21, 111304.5, 96013.79, 102984.4, 103358.1, 125948.5, 91143.04, 107045.3, 110561.7, 110301.8, 95005.36, 103556.0], "type": "scatter", "uid": "c3472dbf-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0, null, null, null, null, null, null, null, null, null, null], "yaxis": "y2", "type": "bar", "uid": "c3472dc0-a6cc-11e9-8637-0008caf36d06"}],
#             {"yaxis": {"overlaying": "y2", "title": "price"}, "yaxis2": {"side": "right", "title": "volume"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('c57369f2-233a-4170-a578-1b0c76c56f38',{});}).then(function(){Plotly.animate('c57369f2-233a-4170-a578-1b0c76c56f38');})
#         });</script>

# %% [markdown]
# ## Однофакторный анализ по каждому признаку

# %% [markdown]
# Построим зависимость спроса от абсолютной разницы цен

# %%
data_plot = [    
    
    go.Scatter(
        x=df['d1'],
        y=df['price_dif'],
        name='price_dif'
    ),
    
    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y2',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="d23da303-e073-4bd2-8d11-d086b615041b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'd23da303-e073-4bd2-8d11-d086b615041b',
#             [{"name": "price_dif", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "type": "scatter", "uid": "c3472dc1-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c3472dc2-a6cc-11e9-8637-0008caf36d06"}],
#             {"yaxis": {"overlaying": "y2", "title": "price"}, "yaxis2": {"side": "right", "title": "volume"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('d23da303-e073-4bd2-8d11-d086b615041b',{});}).then(function(){Plotly.animate('d23da303-e073-4bd2-8d11-d086b615041b');})
#         });</script>

# %% [markdown]
# Посмотрим, как однофакторно объёмы продаж зависят от разности цен

# %%
X = df[['price_dif']].values
y = df['volume'].values

lr = LinearRegression()
lr.fit(X, y)

vol_pred = lr.predict(X)

data_plot = [    
    
    go.Scatter(
        x=df['price_dif'],
        y=df['volume'],
        mode='markers',
        name='недельное наблюдение'
    ),
    
    go.Scatter(
        x=df['price_dif'],
        y=vol_pred,
        name='regression',
        line=dict(
            dash='dash',
            color='blue'
        )
    ),
]

layout = go.Layout(
    xaxis=dict(
        title='разность цен'
    ),
    yaxis=dict(        
        title='объёмы продаж'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="44fe4be5-594e-4300-96d7-68e76b83a617" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '44fe4be5-594e-4300-96d7-68e76b83a617',
#             [{"mode": "markers", "name": "\u043d\u0435\u0434\u0435\u043b\u044c\u043d\u043e\u0435 \u043d\u0430\u0431\u043b\u044e\u0434\u0435\u043d\u0438\u0435", "x": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "type": "scatter", "uid": "c3472dc3-a6cc-11e9-8637-0008caf36d06"}, {"line": {"color": "blue", "dash": "dash"}, "name": "regression", "x": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "y": [129.42925612658757, 115.0408305782379, 116.4772837080938, 126.45712585063939, 136.42787403035345, 115.58268771189772, 116.52235266477152, 116.46128084869444, 130.85801436481677, 95.195846552093, 127.99766044619574, 131.30051386308017, 115.28863124045948, 109.09915595008533, 110.9446959282505, 114.7576758582667, 104.68864685638692, 107.14244483078838, 91.22620208693547, 93.6413291044387, 90.78722384653597, 116.35704218398222, 114.90163871325608, 116.04790246736354, 99.94461647934257, 118.62887444229612, 118.69479584788664, 105.3804011077309, 111.16650373387402, 87.09729144299166, 115.82690423665069, 106.04582452460147, 133.46673196532876, 123.34553647138935, 121.47074175713168, 118.32118095658583, 88.18503000501292, 84.32563706676827, 86.05883477116384, 108.79334885251642, 106.26787598869328, 121.34655453782439], "type": "scatter", "uid": "c3472dc4-a6cc-11e9-8637-0008caf36d06"}],
#             {"xaxis": {"title": "\u0440\u0430\u0437\u043d\u043e\u0441\u0442\u044c \u0446\u0435\u043d"}, "yaxis": {"title": "\u043e\u0431\u044a\u0451\u043c\u044b \u043f\u0440\u043e\u0434\u0430\u0436"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('44fe4be5-594e-4300-96d7-68e76b83a617',{});}).then(function(){Plotly.animate('44fe4be5-594e-4300-96d7-68e76b83a617');})
#         });</script>

# %% [markdown]
# Построим зависимость спроса от относительной разницы цен

# %%
data_plot = [    
    
    go.Scatter(
        x=df['d1'],
        y=df['price_dif_prc'],
        name='price_dif_prc'
    ),
    
    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y2',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="b3bc018f-1239-4606-95d5-3552be9cbaaf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'b3bc018f-1239-4606-95d5-3552be9cbaaf',
#             [{"name": "price_dif_prc", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [-0.21306074354298243, -0.034147649114214716, -0.05954436395370521, -0.22738009523066108, -0.31664009339850324, -0.04672987423703473, -0.05277844677022041, -0.05298832897443835, -0.2871070036120591, 0.18794737745676882, -0.2916148732403491, -0.3179093622087049, -0.04700130549055149, 0.03917198063436298, 0.014252339060351669, -0.034862607013187295, 0.08610734789840331, 0.05759894490130612, 0.22930470208471354, 0.18385270294223988, 0.20880593413989856, -0.055477134137499245, -0.04013853441792473, -0.04972299853125547, 0.13273184748717354, -0.1043888834245207, -0.09565527429479223, 0.07599890185457685, 0.012053814223655372, 0.23531305398842128, -0.04401982890423865, 0.07015874220930397, -0.2865306003446078, -0.1565961408362309, -0.11567604466331854, -0.06447871313461646, 0.20931730282676017, 0.24622969111292273, 0.19647545122357643, 0.033923677886048734, 0.07233708612729832, -0.11750945025376379], "type": "scatter", "uid": "c3472dc5-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c3472dc6-a6cc-11e9-8637-0008caf36d06"}],
#             {"yaxis": {"overlaying": "y2", "title": "price"}, "yaxis2": {"side": "right", "title": "volume"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('b3bc018f-1239-4606-95d5-3552be9cbaaf',{});}).then(function(){Plotly.animate('b3bc018f-1239-4606-95d5-3552be9cbaaf');})
#         });</script>

# %% [markdown]
# Посмотрим, как однофакторно объёмы продаж зависят от относительной разности цен

# %%
X = df[['price_dif_prc']].values
y = df['volume'].values

lr = LinearRegression()
lr.fit(X, y)

vol_pred = lr.predict(X)

data_plot = [    
    
    go.Scatter(
        x=df['price_dif_prc'],
        y=df['volume'],
        mode='markers',
        name='недельное наблюдение'
    ),
    
    go.Scatter(
        x=df['price_dif_prc'],
        y=vol_pred,
        name='regression',
        line=dict(
            dash='dash',
            color='blue'
        )
    ),
    
]

layout = go.Layout(
    xaxis=dict(
        title='относительная разность цен'
    ),
    yaxis=dict(        
        title='объёмы продаж'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="3e205bdc-6322-4262-b605-c02237ae88b1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '3e205bdc-6322-4262-b605-c02237ae88b1',
#             [{"mode": "markers", "name": "\u043d\u0435\u0434\u0435\u043b\u044c\u043d\u043e\u0435 \u043d\u0430\u0431\u043b\u044e\u0434\u0435\u043d\u0438\u0435", "x": [-0.21306074354298243, -0.034147649114214716, -0.05954436395370521, -0.22738009523066108, -0.31664009339850324, -0.04672987423703473, -0.05277844677022041, -0.05298832897443835, -0.2871070036120591, 0.18794737745676882, -0.2916148732403491, -0.3179093622087049, -0.04700130549055149, 0.03917198063436298, 0.014252339060351669, -0.034862607013187295, 0.08610734789840331, 0.05759894490130612, 0.22930470208471354, 0.18385270294223988, 0.20880593413989856, -0.055477134137499245, -0.04013853441792473, -0.04972299853125547, 0.13273184748717354, -0.1043888834245207, -0.09565527429479223, 0.07599890185457685, 0.012053814223655372, 0.23531305398842128, -0.04401982890423865, 0.07015874220930397, -0.2865306003446078, -0.1565961408362309, -0.11567604466331854, -0.06447871313461646, 0.20931730282676017, 0.24622969111292273, 0.19647545122357643, 0.033923677886048734, 0.07233708612729832, -0.11750945025376379], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "type": "scatter", "uid": "c3472dc7-a6cc-11e9-8637-0008caf36d06"}, {"line": {"color": "blue", "dash": "dash"}, "name": "regression", "x": [-0.21306074354298243, -0.034147649114214716, -0.05954436395370521, -0.22738009523066108, -0.31664009339850324, -0.04672987423703473, -0.05277844677022041, -0.05298832897443835, -0.2871070036120591, 0.18794737745676882, -0.2916148732403491, -0.3179093622087049, -0.04700130549055149, 0.03917198063436298, 0.014252339060351669, -0.034862607013187295, 0.08610734789840331, 0.05759894490130612, 0.22930470208471354, 0.18385270294223988, 0.20880593413989856, -0.055477134137499245, -0.04013853441792473, -0.04972299853125547, 0.13273184748717354, -0.1043888834245207, -0.09565527429479223, 0.07599890185457685, 0.012053814223655372, 0.23531305398842128, -0.04401982890423865, 0.07015874220930397, -0.2865306003446078, -0.1565961408362309, -0.11567604466331854, -0.06447871313461646, 0.20931730282676017, 0.24622969111292273, 0.19647545122357643, 0.033923677886048734, 0.07233708612729832, -0.11750945025376379], "y": [127.00236022163163, 112.9788686221867, 114.96950333979755, 128.12473367754214, 135.12107365181703, 113.96508334769659, 114.439180039046, 114.45563093850151, 132.80622331708793, 95.5707088150983, 133.15955727548572, 135.22056095068763, 113.9863585590816, 107.23195996166405, 109.1852009214165, 113.03490815424114, 103.5530915666725, 105.78762532855181, 92.32905623317166, 95.8916558863023, 93.93578211866873, 114.650707427499, 113.44844369715844, 114.19968916864062, 99.89858947223938, 118.48448777449194, 117.79993366371194, 104.34540757144364, 109.357524778857, 91.85811209843868, 113.75266570392422, 104.80316853067578, 132.76104391641405, 122.57657526579999, 119.36919334240598, 115.35626544073918, 93.8957002313853, 91.002448797223, 94.90226489147096, 107.6433302402751, 104.6324264855939, 119.5128985752626], "type": "scatter", "uid": "c3472dc8-a6cc-11e9-8637-0008caf36d06"}],
#             {"xaxis": {"title": "\u043e\u0442\u043d\u043e\u0441\u0438\u0442\u0435\u043b\u044c\u043d\u0430\u044f \u0440\u0430\u0437\u043d\u043e\u0441\u0442\u044c \u0446\u0435\u043d"}, "yaxis": {"title": "\u043e\u0431\u044a\u0451\u043c\u044b \u043f\u0440\u043e\u0434\u0430\u0436"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('3e205bdc-6322-4262-b605-c02237ae88b1',{});}).then(function(){Plotly.animate('3e205bdc-6322-4262-b605-c02237ae88b1');})
#         });</script>

# %% [markdown]
# Построим зависимость спроса от количества запросов в Яндексе

# %%
data_plot = [    
     
    go.Scatter(
        x=df['d1'],
        y=df['yandex_query'],
        name='yandex_query'
    ),

    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y2',        
        title='yandex_query'
    ),
    yaxis2=dict(
        side='right',
        title='volume'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="4e9bda85-007d-4184-af92-2fd6802c1e03" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '4e9bda85-007d-4184-af92-2fd6802c1e03',
#             [{"name": "yandex_query", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "type": "scatter", "uid": "c3472dc9-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c3472dca-a6cc-11e9-8637-0008caf36d06"}],
#             {"yaxis": {"overlaying": "y2", "title": "yandex_query"}, "yaxis2": {"side": "right", "title": "volume"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('4e9bda85-007d-4184-af92-2fd6802c1e03',{});}).then(function(){Plotly.animate('4e9bda85-007d-4184-af92-2fd6802c1e03');})
#         });</script>

# %% [markdown]
# Посмотрим, как однофакторно объёмы продаж зависят от относительной разности цен

# %%
X = df[['yandex_query']].values
y = df['volume'].values

lr = LinearRegression()
lr.fit(X, y)

vol_pred = lr.predict(X)

data_plot = [    
    
    go.Scatter(
        x=df['yandex_query'],
        y=df['volume'],
        mode='markers',
        name='недельное наблюдение'
    ),
    
    go.Scatter(
        x=df['yandex_query'],
        y=vol_pred,
        name='regression',
        line=dict(
            dash='dash',
            color='blue'
        )
    ),
    
]

layout = go.Layout(
    xaxis=dict(
        title='кол-во запросов в Яндексе'
    ),
    yaxis=dict(        
        title='объёмы продаж'
    ),    
)

fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="a27250a0-0888-49d5-acca-12a4d919b74e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'a27250a0-0888-49d5-acca-12a4d919b74e',
#             [{"mode": "markers", "name": "\u043d\u0435\u0434\u0435\u043b\u044c\u043d\u043e\u0435 \u043d\u0430\u0431\u043b\u044e\u0434\u0435\u043d\u0438\u0435", "x": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "type": "scatter", "uid": "c3472dcb-a6cc-11e9-8637-0008caf36d06"}, {"line": {"color": "blue", "dash": "dash"}, "name": "regression", "x": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "y": [149.34278287485017, 149.34278287485017, 149.34278287485017, 84.23336646427803, 84.23336646427803, 84.23336646427803, 84.23336646427803, 84.23336646427803, 57.392397267023796, 57.392397267023796, 57.392397267023796, 57.392397267023796, 59.15413346116694, 59.15413346116694, 59.15413346116694, 59.15413346116694, 89.02202391862852, 89.02202391862852, 89.02202391862852, 89.02202391862852, 89.02202391862852, 114.64202150642834, 114.64202150642834, 114.64202150642834, 114.64202150642834, 141.21090789377632, 141.21090789377632, 141.21090789377632, 141.21090789377632, 177.4523381732924, 177.4523381732924, 177.4523381732924, 177.4523381732924, 177.4523381732924, 140.18379528638008, 140.18379528638008, 140.18379528638008, 140.18379528638008, 111.27499673383815, 111.27499673383815, 111.27499673383815, 111.27499673383815], "type": "scatter", "uid": "c3472dcc-a6cc-11e9-8637-0008caf36d06"}],
#             {"xaxis": {"title": "\u043a\u043e\u043b-\u0432\u043e \u0437\u0430\u043f\u0440\u043e\u0441\u043e\u0432 \u0432 \u042f\u043d\u0434\u0435\u043a\u0441\u0435"}, "yaxis": {"title": "\u043e\u0431\u044a\u0451\u043c\u044b \u043f\u0440\u043e\u0434\u0430\u0436"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('a27250a0-0888-49d5-acca-12a4d919b74e',{});}).then(function(){Plotly.animate('a27250a0-0888-49d5-acca-12a4d919b74e');})
#         });</script>

# %% [markdown]
# ## Двухфакторный анализ

# %% [markdown]
# Также построим одновременно зависимость и от разницы цен, и от количества запросов в Яндексе

# %%
data_plot = [    
    
    go.Scatter(
        x=df['d1'],
        y=df['price_dif'],
        name='price_dif'
    ),
    
    go.Scatter(
        x=df['d1'],
        y=df['yandex_query'],
        name='yandex_query',
        yaxis='y3'
    ),
    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y3',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume',
        overlaying='y3',        
    ),
    
    yaxis3=dict(
        side='left',
        title='yandex_query'
    ),
)


fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="6eb45014-8cd5-49bc-945f-c332b3e51cc5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '6eb45014-8cd5-49bc-945f-c332b3e51cc5',
#             [{"name": "price_dif", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "type": "scatter", "uid": "c3472dcd-a6cc-11e9-8637-0008caf36d06"}, {"name": "yandex_query", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "yaxis": "y3", "type": "scatter", "uid": "c3472dce-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c3472dcf-a6cc-11e9-8637-0008caf36d06"}],
#             {"yaxis": {"overlaying": "y3", "title": "price"}, "yaxis2": {"overlaying": "y3", "side": "right", "title": "volume"}, "yaxis3": {"side": "left", "title": "yandex_query"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('6eb45014-8cd5-49bc-945f-c332b3e51cc5',{});}).then(function(){Plotly.animate('6eb45014-8cd5-49bc-945f-c332b3e51cc5');})
#         });</script>

# %% [markdown]
# # Построение модели

# %% [markdown]
# Для данной задачи прогнозирования в качестве метода были выбраны линейные регрессии. Это мотивированно тем, что данных очень мало и нужно снизить переобучение к минимуму. По этой же причине признаки для линейных моделей были взяты только самые простые.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# У нас есть два сильно коррелированных признака: price_dif_prc и price_dif. Чтобы избежать переобучения, выберем из них только один, который имеет большее влияние на модель. Чтобы это сделать, нормируем все признаки, обучим линейную регрессию и оставим тот, у которого вес будет больший по модулю

# %%
features = ['price_dif_prc', 'price_dif', 'avg_price', 'yandex_query']

X = scaler.fit_transform(df[features].values)
y = df['volume'].values

lr = LinearRegression()
lr.fit(X, y)

vol_pred = lr.predict(X)

# %%
pd.Series(lr.coef_, index=features, name="feature's coefs")
# Out:
# price_dif_prc    -1.159308
# price_dif       -19.447179
# avg_price         5.589497
# yandex_query     38.431285
# Name: feature's coefs, dtype: float64

# %% [markdown]
# вес у price_dif много больше по модулю, поэтому его и оставим

# %%
features = ['price_dif', 'avg_price', 'yandex_query']

X = df[features].values
y = df['volume'].values

lr = LinearRegression()
lr.fit(X, y)

vol_pred = lr.predict(X)

# %% [markdown]
# Корень из среднеквадратичной ошибки:

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df['volume'], vol_pred) ** 0.5
# Out:
# 14.160246694580769

# %% [markdown]
# Построим график предсказаний модели и имеющихся признаков

# %%
data_plot = [    
    
    go.Scatter(
        x=df['d1'],
        y=df['price_dif'],
        name='price_dif'
    ),
    
    go.Scatter(
        x=df['d1'],
        y=df['yandex_query'],
        name='yandex_query',
        yaxis='y3'
    ),
    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
    
    go.Bar(
        x=df['d1'],
        y=vol_pred,
        name='volume_pred',
        yaxis='y2',
        opacity=0.5
    ),    
]

layout = go.Layout(
    yaxis=dict(
        overlaying='y2',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume'
    ),    
)


layout = go.Layout(
    yaxis=dict(
        overlaying='y3',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume',
        overlaying='y3',        
    ),
    
    yaxis3=dict(
        side='left',
        title='yandex_query'
    ),
)


fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="893b1968-0e11-468b-b293-302f70ff29dd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '893b1968-0e11-468b-b293-302f70ff29dd',
#             [{"name": "price_dif", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "type": "scatter", "uid": "c4b7a7c8-a6cc-11e9-8637-0008caf36d06"}, {"name": "yandex_query", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "yaxis": "y3", "type": "scatter", "uid": "c4b7a7c9-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c4b7a7ca-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume_pred", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", ...
#             {"yaxis": {"overlaying": "y3", "title": "price"}, "yaxis2": {"overlaying": "y3", "side": "right", "title": "volume"}, "yaxis3": {"side": "left", "title": "yandex_query"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('893b1968-0e11-468b-b293-302f70ff29dd',{});}).then(function(){Plotly.animate('893b1968-0e11-468b-b293-302f70ff29dd');})
#         });</script>

# %% [markdown]
# Как видно, мы уже получили неплохую модель. Но у неё есть недостаток. А именно LinearRegression из пакета sklearn.linear_model предполагает то, что целевая переменная - объём продаж нормально распределена. Но это заведомо неверное предположение, так как объём продаж неотрицателен. Чтобы улучшить модель посмотрим на распределение целевой переменной

# %%
data_plot = [
    go.Histogram(
        x=df['volume'],
        nbinsx=20,
        opacity=0.5
    )
]

layout = go.Layout(
    xaxis=dict(
        title='объемы продаж'
    ),
    
    yaxis=dict(        
        title='количество'
    )
)



fig = go.Figure(data=data_plot, layout=layout)
ply.iplot(fig)
# Out:
# <div id="e875f7c2-6c03-481a-9438-3cda6b4bb2d6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'e875f7c2-6c03-481a-9438-3cda6b4bb2d6',
#             [{"nbinsx": 20, "opacity": 0.5, "x": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "type": "histogram", "uid": "c4b7a7cc-a6cc-11e9-8637-0008caf36d06"}],
#             {"xaxis": {"title": "\u043e\u0431\u044a\u0435\u043c\u044b \u043f\u0440\u043e\u0434\u0430\u0436"}, "yaxis": {"title": "\u043a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('e875f7c2-6c03-481a-9438-3cda6b4bb2d6',{});}).then(function(){Plotly.animate('e875f7c2-6c03-481a-9438-3cda6b4bb2d6');})
#         });</script>

# %% [markdown]
# При таком распределении естественно считать объём гамма распределённым (а не нормально). Чтобы построить такую линейную модель воспользуемся GLM из пакета statsmodels

# %% [markdown]
# Как и ранее проведём отбор из двух признаков price_dif_prc, price_dif.

# %%
features = ['price_dif_prc', 'price_dif', 'avg_price', 'yandex_query']

X = df[features].copy()
X.loc[:] = scaler.fit_transform(X.values)

X['const'] = 1
y = df[['volume']]

# %% [markdown]
# Фунцкцию связи возьмём логарифмической, таким образом *систематическая компонента модели* $\mu=f(X \beta)$ будет принимать только положительные значения

# %%
gamma_model = sm.GLM(y, X, family=sm.families.Gamma(link=sm.families.links.log))

gamma_results = gamma_model.fit()
vol_pred_gamma = gamma_results.mu

# %%
gamma_results.params
# Out:
# price_dif_prc   -0.085615
# price_dif       -0.080446
# avg_price        0.042993
# yandex_query     0.352191
# const            4.647999
# dtype: float64

# %% [markdown]
# в данном случае price_dif_prc имеет больший по модулю вес

# %%
features = ['price_dif_prc', 'avg_price', 'yandex_query']

X = df[features].copy()
X['const'] = 1
y = df[['volume']]

# %%
gamma_model = sm.GLM(y, X, family=sm.families.Gamma(link=sm.families.links.log))

gamma_results = gamma_model.fit()
vol_pred_gamma = gamma_results.mu

# %%
print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 volume   No. Observations:                   42
# Model:                            GLM   Df Residuals:                       38
# Model Family:                   Gamma   Df Model:                            3
# Link Function:                    log   Scale:                        0.020117
# Method:                          IRLS   Log-Likelihood:                -170.48
# Date:                Mon, 15 Jul 2019   Deviance:                      0.76463
# Time:                        09:50:02   Pearson chi2:                    0.764
# No. Iterations:                     9   Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# price_dif_prc    -0.9896      0.230     -4.298      0.000      -1.441      -0.538
# avg_price      1.617e-06   1.88e-06      0.859      0.390   -2.07e-06    5.31e-06
# yandex_query   3.159e-05   2.02e-06     15.623      0.000    2.76e-05    3.56e-05
# const             3.4287      0.197     17.412      0.000       3.043       3.815
# =================================================================================

# %% [markdown]
# по коэффициентам модели видно, что основной рыночный фактор это число запросов в Яндексе

# %% [markdown]
# Построим график предсказаний обобщенной линейной модели и имеющихся признаков

# %%
data_plot = [    
    
    go.Scatter(
        x=df['d1'],
        y=df['price_dif'],
        name='price_dif'
    ),
    
    go.Scatter(
        x=df['d1'],
        y=df['yandex_query'],
        name='yandex_query',
        yaxis='y3'
    ),
    
    go.Bar(
        x=df['d1'],
        y=df['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
    
    go.Bar(
        x=df['d1'],
        y=vol_pred_gamma,
        name='volume_pred_gamma',
        yaxis='y2',
        opacity=0.5
    ),
]



layout = go.Layout(
    yaxis=dict(
        overlaying='y3',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume',
        overlaying='y3',        
    ),
    
    yaxis3=dict(
        side='left',
        title='yandex_query'
    ),
)


fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="0ee898d8-6541-45eb-a132-7d22823665a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '0ee898d8-6541-45eb-a132-7d22823665a8',
#             [{"name": "price_dif", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0], "type": "scatter", "uid": "c4b7a7cd-a6cc-11e9-8637-0008caf36d06"}, {"name": "yandex_query", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0], "yaxis": "y3", "type": "scatter", "uid": "c4b7a7ce-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 124.0, 123.0, 95.0, 139.0, 147.0, 147.0, 166.0, 146.0, 183.0, 158.0, 221.0, 185.0, 172.0, 165.0, 99.0, 91.0, 98.0, 111.0, 96.0, 103.0], "yaxis": "y2", "type": "bar", "uid": "c4b7a7cf-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume_pred_gamma", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-1 ...
#             {"yaxis": {"overlaying": "y3", "title": "price"}, "yaxis2": {"overlaying": "y3", "side": "right", "title": "volume"}, "yaxis3": {"side": "left", "title": "yandex_query"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('0ee898d8-6541-45eb-a132-7d22823665a8',{});}).then(function(){Plotly.animate('0ee898d8-6541-45eb-a132-7d22823665a8');})
#         });</script>

# %% [markdown]
# # Прогноз на неразмеченной части выборки

# %%
vol_pred = lr.predict(df_full[features].values)

# %%
X = df_full[features].copy()
X['const'] = 1

vol_pred_gamma = gamma_model.predict(gamma_results.params.values, X)

# %%
data_plot = [    
    
    go.Scatter(
        x=df_full['d1'],
        y=df_full['price_dif'],
        name='price_dif'
    ),
    
    go.Scatter(
        x=df_full['d1'],
        y=df_full['yandex_query'],
        name='yandex_query',
        yaxis='y3'
    ),
    
    go.Bar(
        x=df_full['d1'],
        y=df_full['volume'],
        name='volume',
        yaxis='y2',
        opacity=0.5
    ),
    
    go.Bar(
        x=df_full['d1'],
        y=vol_pred_gamma,
        name='volume_pred_gamma',
        yaxis='y2',
        opacity=0.5
    ),
    
    go.Bar(
        x=df_full['d1'],
        y=vol_pred,
        name='volume_pred',
        yaxis='y2',
        opacity=0.5
    ),
    
    
]



layout = go.Layout(
    yaxis=dict(
        overlaying='y3',        
        title='price'
    ),
    yaxis2=dict(
        side='right',
        title='volume',
        overlaying='y3',        
    ),
    
    yaxis3=dict(
        side='left',
        title='yandex_query'
    ),
)


fig = go.Figure(data=data_plot, layout=layout)

ply.iplot(fig)
# Out:
# <div id="7628e333-a3b9-46d2-bff9-47024fd25b18" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '7628e333-a3b9-46d2-bff9-47024fd25b18',
#             [{"name": "price_dif", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [-21987.399999999994, -3681.399999999994, -5508.959999999992, -18206.039999999994, -30891.550000000003, -4370.789999999994, -5566.300000000003, -5488.599999999991, -23805.170000000013, 21566.83, -20166.020000000004, -24368.149999999994, -3996.6699999999983, 3878.029999999999, 1530.0, -3321.149999999994, 9489.400000000009, 6367.5, 26617.300000000003, 23544.600000000006, 27175.800000000003, -5355.979999999996, -3504.3099999999977, -4962.669999999998, 15525.099999999991, -8246.369999999995, -8330.23999999999, 8609.299999999988, 1247.800000000003, 31870.399999999994, -4681.5, 7762.699999999997, -27124.17, -14247.25, -11862.0, -7854.899999999994, 30486.499999999985, 35396.69999999998, 33191.600000000006, 4267.100000000006, 7480.189999999988, -11704.0, 10637.910000000003, -1310.8999999999942, 19741.59999999999, -6845.800000000003, 10753.060000000012, 17368.199999999997, 14977.0, 1391.5, 17081.539999999994, -18272.83], "type": "scatter", "uid": "c5a205ca-a6cc-11e9-8637-0008caf36d06"}, {"name": "yandex_query", "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [43602.0, 43602.0, 43602.0, 24458.0, 24458.0, 24458.0, 24458.0, 24458.0, 16566.0, 16566.0, 16566.0, 16566.0, 17084.0, 17084.0, 17084.0, 17084.0, 25866.0, 25866.0, 25866.0, 25866.0, 25866.0, 33399.0, 33399.0, 33399.0, 33399.0, 41211.0, 41211.0, 41211.0, 41211.0, 51867.0, 51867.0, 51867.0, 51867.0, 51867.0, 40909.0, 40909.0, 40909.0, 40909.0, 32409.0, 32409.0, 32409.0, 32409.0, 32409.0, 42146.0, 42146.0, 42146.0, 42146.0, 36013.0, 36013.0, 36013.0, 36013.0, 33290.0], "yaxis": "y3", "type": "scatter", "uid": "c5a205cb-a6cc-11e9-8637-0008caf36d06"}, {"name": "volume", "opacity": 0.5, "x": ["2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04"], "y": [197.0, 155.0, 124.0, 131.0, 109.0, 83.0, 70.0, 56.0, 65.0, 47.0, 68.0, 83.0, 63.0, 59.0, 58.0, 64.0, 70.0, 75.0, 68.0, 81.0, 86.0, 116.0, 1 ...

# %% [markdown]
# Можно видеть, что обе посроенные регрессии делают примерно одинаковый прогноз. Но в качестве результирующего прогноза будем использовать volume_pred_gamma, поскольку оно,как указано выше лучше описывает данные

# %% [markdown]
# Сохраняем прогноз модели в csv файл *data_result.csv*

# %%
df_full\
.assign(volume_predict=vol_pred_gamma)\
.to_csv('data_result.csv')
